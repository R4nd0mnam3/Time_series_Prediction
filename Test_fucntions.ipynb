# %%
import pandas as pd

# %%
df = pd.read_excel("Index.xlsx")
df
# Out:
#                    Date      SPOT        Q1        Q2        Q3        Q4  \
# 0   2023-04-24 00:00:00  7.212716  7.264444  7.313722  7.363333  7.457631
# 1   2023-05-01 00:00:00  7.321166  7.360877  7.413733  7.466968  7.520000
# 2   2023-05-08 00:00:00  7.360211  7.360211  7.400000  7.400000  7.482110
# 3   2023-05-15 00:00:00  7.380000  7.380000  7.335030  7.335484  7.400000
# 4   2023-05-22 00:00:00  7.400000  7.400000  7.335030  7.335484  7.400000
# ..                  ...       ...       ...       ...       ...       ...
# 85  2024-12-16 00:00:00  7.810000  7.810000  7.810000  7.850000  7.870000
# 86  2024-12-23 00:00:00  7.970000  7.970000  7.970000  8.010000  8.030000
# 87  2024-12-30 00:00:00  7.970000  7.970000  7.970000  8.010000  8.030000
# 88  2025-01-06 00:00:00  7.970000  7.970000  7.970000  8.010000  8.030000
# 89  2025-01-13 00:00:00  8.020000  8.030000  8.020000  8.070000  8.080000
#
#           Q5        Q6        Q7        Q8        Q9       Q10       Q11  Q12
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")
df
# Out:
#          Date      SPOT        Q1        Q2        Q3        Q4        Q5  \
# 0  2023-04-24  7.212716  7.264444  7.313722  7.363333  7.457631  7.553137
# 1  2023-05-01  7.321166  7.360877  7.413733  7.466968  7.520000  7.590504
# 2  2023-05-08  7.360211  7.360211  7.400000  7.400000  7.482110  7.565130
# 3  2023-05-15  7.380000  7.380000  7.335030  7.335484  7.400000  7.534828
# 4  2023-05-22  7.400000  7.400000  7.335030  7.335484  7.400000  7.534828
# ..        ...       ...       ...       ...       ...       ...       ...
# 85 2024-12-16  7.810000  7.810000  7.810000  7.850000  7.870000  8.050000
# 86 2024-12-23  7.970000  7.970000  7.970000  8.010000  8.030000  8.220000
# 87 2024-12-30  7.970000  7.970000  7.970000  8.010000  8.030000  8.220000
# 88 2025-01-06  7.970000  7.970000  7.970000  8.010000  8.030000  8.220000
# 89 2025-01-13  8.020000  8.030000  8.020000  8.070000  8.080000  8.270000
#
#           Q6        Q7        Q8        Q9       Q10       Q11  Q12
# ...

# %%
columns_to_drop = ["Q8", "Q9", "Q10", "Q11", "Q12"]
df.drop(columns=columns_to_drop, inplace=True)
df
# Out:
#          Date      SPOT        Q1        Q2        Q3        Q4        Q5  \
# 0  2023-04-24  7.212716  7.264444  7.313722  7.363333  7.457631  7.553137
# 1  2023-05-01  7.321166  7.360877  7.413733  7.466968  7.520000  7.590504
# 2  2023-05-08  7.360211  7.360211  7.400000  7.400000  7.482110  7.565130
# 3  2023-05-15  7.380000  7.380000  7.335030  7.335484  7.400000  7.534828
# 4  2023-05-22  7.400000  7.400000  7.335030  7.335484  7.400000  7.534828
# ..        ...       ...       ...       ...       ...       ...       ...
# 85 2024-12-16  7.810000  7.810000  7.810000  7.850000  7.870000  8.050000
# 86 2024-12-23  7.970000  7.970000  7.970000  8.010000  8.030000  8.220000
# 87 2024-12-30  7.970000  7.970000  7.970000  8.010000  8.030000  8.220000
# 88 2025-01-06  7.970000  7.970000  7.970000  8.010000  8.030000  8.220000
# 89 2025-01-13  8.020000  8.030000  8.020000  8.070000  8.080000  8.270000
#
#           Q6        Q7
# 0   7.650935  7.750000
# 1   7.662455  7.735087
# ...

# %%
import pandas as pd
business_days = pd.bdate_range(start="2020-01-02", end="2020-01-08")
for business_day in business_days :
    print(business_day)
# Out:
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-06 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00

# %%
df_test = pd.DataFrame(data = {"fruits": ["banana", "apple"], "Date": [pd.to_datetime("2020-01-02"), pd.to_datetime("2020-01-06")]})

for i in range(len(df_test)) :
    print(i)
    print(df_test.iloc[i])
# Out:
# 0
# fruits                 banana
# Date      2020-01-02 00:00:00
# Name: 0, dtype: object
# 1
# fruits                  apple
# Date      2020-01-06 00:00:00
# Name: 1, dtype: object
